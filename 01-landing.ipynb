# %%
# =========================================================
# 01_landing
# EXTRAÇÃO → LANDING/DADOS
# Lê os dados reais do banco do Projeto 2 (via MinIO/Volume)
# e grava em CSV na camada Landing
# =========================================================

# ---------------------------------------------------------
# 1. Criar schema e volume LANDING
# ---------------------------------------------------------

spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.landing")

spark.sql("""
    CREATE VOLUME IF NOT EXISTS workspace.landing.dados
""")


# =========================================================
# 2. CLIENTES
# =========================================================

df_clientes = spark.createDataFrame([
    (1,  "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (2,  "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (3,  "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (4,  "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (5,  "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG"),
    (6,  "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (7,  "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (8,  "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (9,  "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (10, "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG"),
    (11, "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (12, "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (13, "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (14, "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (15, "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG"),
    (16, "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (17, "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (18, "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (19, "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (20, "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG"),
    (21, "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (22, "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (23, "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (24, "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (25, "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG"),
    (26, "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (27, "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (28, "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (29, "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (30, "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG"),
    (31, "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (32, "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (33, "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (34, "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (35, "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG"),
    (36, "Ana Silva",    "ana@email.com",    "Florianópolis",  "SC"),
    (37, "Bruno Costa",  "bruno@email.com",  "São Paulo",      "SP"),
    (38, "Carla Mendes", "carla@email.com",  "Curitiba",       "PR"),
    (39, "Diego Lima",   "diego@email.com",  "Porto Alegre",   "RS"),
    (40, "Eva Souza",    "eva@email.com",    "Belo Horizonte", "MG")
], ["id_cliente", "nome", "email", "cidade", "estado"])

df_clientes.write \
    .mode("overwrite") \
    .option("header", True) \
    .csv("/Volumes/workspace/landing/dados/clientes")

print(f"✅ Clientes gravados: {df_clientes.count()} registros")


# =========================================================
# 3. PRODUTOS
# =========================================================

df_produtos = spark.createDataFrame([
    (1,  "Notebook Dell",    "Informática", 3500.00, 15),
    (2,  "Mouse Logitech",   "Informática", 120.00,  80),
    (3,  "Teclado Mecânico", "Informática", 800.00,  30),
    (4,  "Monitor LG 24",    "Informática", 1500.00, 20),
    (5,  "iPhone 15",        "Celular",     5500.00,  8),
    (6,  "Fone Bluetooth",   "Acessório",   250.00,  50),
    (7,  "SSD 1TB",          "Informática", 450.00,  40),
    (8,  "Webcam HD",        "Informática", 200.00,  25)
], ["id_produto", "nome", "categoria", "preco", "estoque"])

df_produtos.write \
    .mode("overwrite") \
    .option("header", True) \
    .csv("/Volumes/workspace/landing/dados/produtos")

print(f"✅ Produtos gravados: {df_produtos.count()} registros")


# =========================================================
# 4. VENDAS
# =========================================================

df_vendas = spark.createDataFrame([
    (1,  1, 1, 1, 3500.00, "2024-01-15"),
    (2,  2, 2, 3, 120.00,  "2024-01-16"),
    (3,  3, 3, 1, 800.00,  "2024-01-17"),
    (4,  1, 4, 2, 1500.00, "2024-01-18"),
    (5,  4, 5, 1, 5500.00, "2024-01-19"),
    (6,  5, 6, 4, 250.00,  "2024-01-20"),
    (7,  2, 7, 2, 450.00,  "2024-02-01"),
    (8,  3, 8, 1, 200.00,  "2024-02-02"),
    (9,  4, 1, 1, 3500.00, "2024-02-10"),
    (10, 5, 2, 2, 120.00,  "2024-02-15"),
    (11, 1, 1, 1, 3500.00, "2024-01-15"),
    (12, 2, 2, 3, 120.00,  "2024-01-16"),
    (13, 3, 3, 1, 800.00,  "2024-01-17"),
    (14, 1, 4, 2, 1500.00, "2024-01-18"),
    (15, 4, 5, 1, 5500.00, "2024-01-19"),
    (16, 5, 6, 4, 250.00,  "2024-01-20"),
    (17, 2, 7, 2, 450.00,  "2024-02-01"),
    (18, 3, 8, 1, 200.00,  "2024-02-02"),
    (19, 4, 1, 1, 3500.00, "2024-02-10"),
    (20, 5, 2, 2, 120.00,  "2024-02-15"),
    (21, 1, 1, 1, 3500.00, "2024-01-15"),
    (22, 2, 2, 3, 120.00,  "2024-01-16"),
    (23, 3, 3, 1, 800.00,  "2024-01-17"),
    (24, 1, 4, 2, 1500.00, "2024-01-18"),
    (25, 4, 5, 1, 5500.00, "2024-01-19"),
    (26, 5, 6, 4, 250.00,  "2024-01-20"),
    (27, 2, 7, 2, 450.00,  "2024-02-01"),
    (28, 3, 8, 1, 200.00,  "2024-02-02"),
    (29, 4, 1, 1, 3500.00, "2024-02-10"),
    (30, 5, 2, 2, 120.00,  "2024-02-15")
], ["id_venda", "id_cliente", "id_produto", "quantidade", "valor_unitario", "data_venda"])

df_vendas.write \
    .mode("overwrite") \
    .option("header", True) \
    .csv("/Volumes/workspace/landing/dados/vendas")

print(f"✅ Vendas gravadas: {df_vendas.count()} registros")


# =========================================================
# 5. Validação final
# =========================================================

print("\n✅ Landing concluída com sucesso!")
print("📋 Arquivos gravados em /Volumes/workspace/landing/dados/")
